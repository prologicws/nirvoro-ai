# %%
import requests
from pymongo import MongoClient
import datetime

# %%
# Event Registry API details
API_URL = "https://eventregistry.org/api/v1/article/getArticles"
API_KEY = "9d8ccead-0c1f-448f-9ceb-b85f4def0063"

# %%
# MongoDB Setup
client = MongoClient('mongodb://localhost:27017/')  # Update with your MongoDB connection URI
db = client['news_database']
collection = db['news_articles']

# %%
def is_duplicate_article(new_article, existing_articles):
    """
    Check if the new article is a duplicate based on title similarity and source.
    If the title matches exactly and the source is the same, it's considered a duplicate.
    """
    for article_item in existing_articles:
        # Ensure the existing article has a title and source
        if 'title' in article_item and 'source' in article_item:
            if article_item['title_or'] == new_article['title_or'] and article_item['source'] == new_article['source']:
                print(f"Duplicate title found in the same source: {article_item['title_or']} (Source: {article_item['source']})")
                return True
        else:
            # If either title or source is missing, we can't reliably check for duplicates
            continue
            
    return False

# %%
def determine_category(article_content):
    """
    Determines the category of the article based on its content.
    """
    # Define keywords for each category
    categories = {
        #"Breaking": ["breaking", "urgent", "just in"],
        "World": ["government", "policy", "election", "political", "politics", "weather", "storm", "temperature", "forecast", "climate", "environment", "sustainability", "nature"],
        "Business": ["business", "market", "stocks", "finance", "economy"],
        "Technology": ["research", "scientists", "study", "laboratory", "experiment", "science"],
        "Sports": ["game", "match", "tournament", "league", "athlete"],
        #"Art & Culture": ["art", "museum", "culture", "festival", "heritage"],
        "Entertainment": ["celebrity", "movie", "music", "show", "award", "art", "museum", "culture", "festival", "heritage", "travel", "tourism", "destination", "flight", "hotel"],
        #"Travel": ["travel", "tourism", "destination", "flight", "hotel"],
        #"Weather": ["weather", "storm", "temperature", "forecast"],
        #"Earth": ["climate", "environment", "sustainability", "nature"],
        #"Local": ["local", "community", "neighborhood", "town"]
    }

    # Default category
    assigned_category = "World"

    # Check for category keywords
    for category, keywords in categories.items():
        if any(keyword in article_content.lower() for keyword in keywords):
            assigned_category = category
            break
    print(f"Assigned category: {assigned_category}")
    return assigned_category

# Example usage with an article
#article_content = """The government has announced a new policy that will affect the election process."""
#category = determine_category(article_content)
#print(f"Assigned category: {category}")  # Should print "Politics"

# %%
# API request payload
payload = {
    "action": "getArticles",
    "keyword": "Tesla Inc",
    "sourceLocationUri": [
        "http://en.wikipedia.org/wiki/United_States",
        "http://en.wikipedia.org/wiki/United_Kingdom",
        "https://en.wikipedia.org/wiki/India"
    ],
    "ignoreSourceGroupUri": "paywall/paywalled_sources",
    "articlesPage": 1,
    "articlesCount": 100,
    "articlesSortBy": "date",
    "articlesSortByAsc": False,
    "dataType": ["news", "pr"],
    "forceMaxDataTimeWindow": 31,
    "resultType": "articles",
    "apiKey": API_KEY
}

# Fetch data from the API
response = requests.get(API_URL, json=payload)
if response.status_code != 200:
    print("Error fetching data:", response.status_code, response.text)
    exit()

# Parse response JSON
data = response.json()
articles = data.get("articles", {}).get("results", [])
print(len(articles))
# Out:
# 100

# %%
# Process and insert into MongoDB
news_data = []
category = "";
skipped_count = 0;
current_time = datetime.datetime.utcnow().isoformat()  # Current timestamp in UTC

for article in articles:
    uri = article.get("uri")
    print(f"My uri: "+uri)
    print(len(article.get("authors")))
    category = determine_category(article.get("body"))


    # Check if the article already exists in MongoDB
    if collection.find_one({"uri": uri}):
        skipped_count += 1
        continue  # Skip duplicate entry
        
    news_item = {
        "uri": article.get("uri"),
        "lang": article.get("lang"),
        "title_or": article.get("title"),
        "description_or": article.get("body"),
        "category": category,
        "url": article.get("url"),
        "published_time": article.get("dateTimePub"),
        "fetched_at": current_time,
        "image": article.get("image"),
        "images": [article.get("image")] if article.get("image") else [],
        "source": article.get("source", {}).get("title"),
        "sentiment": article.get("sentiment"),
        "wgt": article.get("wgt"),
        "relevance": article.get("relevance"),
        "author_name": article["authors"][0]["name"] if "authors" in article and article["authors"] else None,
        "likes": 0,
        "comments": 0,
        "shares": 0
    }
    news_data.append(news_item)
    #inserted_count = len(news_data)


if news_data:
    collection.insert_many(news_data)
    inserted_count = len(news_data)

print(f"Inserted {inserted_count} new articles, skipped {skipped_count} duplicates.")
# Out:
# My uri: p-8584110393
# 0
# Assigned category: Business
# My uri: 8584101892
# 1
# Assigned category: World
# My uri: p-8584088446
# 1
# Assigned category: Business
# My uri: 8584073779
# 0
# Assigned category: World
# My uri: 8584068577
# 1
# Assigned category: World
# My uri: 8584042033
# 0
# Assigned category: Business
# My uri: 8584028948
# 1
# Assigned category: World
# My uri: p-8584015395
# 1
# Assigned category: Business
# My uri: 8584000382
# 0
# Assigned category: World
# My uri: 2025-03-656083303
# 1
# Assigned category: World
# My uri: 8583968836
# 0
# Assigned category: World
# My uri: 8583963390
# 0
# Assigned category: Business
# My uri: 8583926887
# 0
# Assigned category: World
# My uri: 8583895449
# 1
# Assigned category: World
# My uri: 2025-03-656018163
# 1
# Assigned category: Technology
# My uri: p-8583874316
# 1
# Assigned category: Business
# My uri: 8583808348
# 1
# Assigned category: World
# My uri: 8583792978
# 0
# Assigned category: World
# My uri: 8583742332
# 0
# Assigned category: Business
# My uri: 2025-03-655938988
# 1
# Assigned category: World
# My uri: 8583607117
# 0
# Assigned category: Business
# My uri: 8583601888
# 0
# Assigned category: World
# My uri: 8583597490
# 0
# Assigned category: World
# My uri: 2025-03-655797581
# 1
# Assigned category: World
# My uri: 8583569980
# 0
# Assigned category: World
# My uri: p-8583557949
# 0
# Assigned category: World
# My uri: p-8583557950
# 0
# Assigned category: World
# My uri: p-8583553028
# 1
# Assigned category: Business
# My uri: p-8583553023
# 1
# Assigned category: Business
# My uri: 8583524462
# 0
# Assigned category: Business
# My uri: 8583524468
# 0
# Assigned category: Business
# My uri: 8583524461
# 0
# Assigned category: Business
# My uri: 8583524465
# 0
# Assigned category: Business
# My uri: p-8583494322
# 0
# Assigned category: World
# My uri: p-8583506146
# 0
# Assigned category: World
# My uri: p-8583507146
# 0
# Assigned category: Business
# My uri: p-8583502418
# 0
# Assigned category: Business
# My uri: p-8583502419
# 0
# Assigned category: Business
# My uri: p-8583499736
# 1
# Assigned category: Business
# My uri: p-8583499743
# 1
# Assigned category: World
# My uri: p-8583498837
# 0
# Assigned category: Business
# My uri: p-2025-03-655727305
# 0
# Assigned category: Entertainment
# My uri: 2025-03-655724483
# 0
# Assigned category: Entertainment
# My uri: 8583456697
# 1
# Assigned category: World
# My uri: 2025-03-655661406
# 0
# Assigned category: World
# My uri: 8583336059
# 1
# Assigned category: World
# My uri: p-8583278564
# 0
# Assigned category: World
# My uri: p-8583275926
# 0
# Assigned category: World
# My uri: p-8583251026
# 0
# Assigned category: World
# My uri: p-8583229492
# 0
# Assigned category: World
# My uri: p-8583171570
# 0
# Assigned category: World
# My uri: 2025-03-655461974
# 0
# Assigned category: World
# My uri: p-8583033520
# 0
# Assigned category: World
# My uri: p-8583041220
# 0
# Assigned category: World
# My uri: 8583053604
# 1
# Assigned category: World
# My uri: 8583015693
# 1
# Assigned category: World
# My uri: p-8583011450
# 0
# Assigned category: World
# My uri: p-2025-03-655374683
# 0
# Assigned category: World
# My uri: 8582991028
# 0
# Assigned category: World
# My uri: 2025-03-655361590
# 0
# Assigned category: Business
# My uri: 2025-03-655319580
# 0
# Assigned category: Business
# My uri: 2025-03-655318695
# 0
# Assigned category: World
# My uri: 2025-03-655315359
# 1
# Assigned category: Entertainment
# My uri: p-8582888312
# 1
# Assigned category: World
# My uri: 8582882790
# 1
# Assigned category: World
# My uri: p-8582869024
# 1
# Assigned category: World
# My uri: 2025-03-655269860
# 0
# Assigned category: Business
# My uri: 2025-03-655265937
# 0
# Assigned category: Business
# My uri: 8582828143
# 0
# Assigned category: World
# My uri: 8582829154
# 0
# Assigned category: World
# My uri: 8582822086
# 0
# Assigned category: World
# My uri: 2025-03-655249811
# 0
# Assigned category: Business
# My uri: 2025-03-655249647
# 0
# Assigned category: World
# My uri: 2025-03-655247594
# 0
# Assigned category: Business
# My uri: 2025-03-655247515
# 0
# Assigned category: World
# My uri: 2025-03-655247514
# 0
# Assigned category: World
# My uri: 2025-03-655230921
# 1
# Assigned category: World
# My uri: 8582767294
# 0
# Assigned category: Business
# My uri: 8582766727
# 0
# Assigned category: World
# My uri: 2025-03-655219578
# 1
# Assigned category: Business
# My uri: 2025-03-655219541
# 1
# Assigned category: Business
# My uri: 8582721328
# 0
# Assigned category: World
# My uri: 8582681478
# 0
# Assigned category: Business
# My uri: 8582567774
# 0
# Assigned category: Business
# My uri: 8582546840
# 0
# Assigned category: Entertainment
# My uri: 2025-03-655069834
# 0
# Assigned category: World
# My uri: 8582459846
# 0
# Assigned category: World
# My uri: 2025-03-655028469
# 0
# Assigned category: World
# My uri: p-8582429915
# 1
# Assigned category: World
# My uri: 8582420479
# 0
# Assigned category: World
# My uri: 2025-03-654996768
# 1
# Assigned category: World
# My uri: p-8582398323
# 1
# Assigned category: Business
# My uri: p-8582398328
# 1
# Assigned category: Business
# My uri: 8582371641
# 1
# Assigned category: Business
# My uri: p-8582326568
# 1
# Assigned category: Business
# My uri: p-8582283503
# 1
# Assigned category: Business
# My uri: 8582255927
# 1
# Assigned category: Business
# My uri: 2025-03-654871585
# 0
# Assigned category: Entertainment
# My uri: 2025-03-654871583
# 0
# Assigned category: Business
# My uri: 2025-03-654871587
# 0
# Assigned category: Business
# Inserted 100 new articles, skipped 0 duplicates.

# %%
# Close MongoDB connection
client.close()
