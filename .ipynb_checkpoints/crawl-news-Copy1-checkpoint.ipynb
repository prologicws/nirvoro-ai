# %%
# !pip install feedparser pymongo
# !pip install rapidfuzz
# !pip install selenium

import feedparser
from pymongo import MongoClient
from datetime import datetime
from rapidfuzz import fuzz
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
# Out:
# Requirement already satisfied: feedparser in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (6.0.11)
# Requirement already satisfied: pymongo in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (4.10.1)
# Requirement already satisfied: sgmllib3k in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from feedparser) (1.0.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from pymongo) (2.7.0)
# Requirement already satisfied: rapidfuzz in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (3.10.0)
# Requirement already satisfied: selenium in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (4.25.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from selenium) (1.26.16)
# Requirement already satisfied: trio~=0.17 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from selenium) (0.26.2)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions~=4.9 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from selenium) (4.9.0)
# Requirement already satisfied: websocket-client~=1.8 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (24.2.0)
# Requirement already satisfied: sortedcontainers in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/dibyendu/anaconda3/lib/python3.11/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
# List of RSS feed URLs
rss_feeds = {
    "BBC News": "http://feeds.bbci.co.uk/news/rss.xml",
    #"CNN": "http://rss.cnn.com/rss/edition.rss",
    #"Reuters": "http://feeds.reuters.com/reuters/topNews",
    #"The New York Times": "https://rss.nytimes.com/services/xml/rss/nyt/HomePage.xml",
    #"The Guardian": "https://www.theguardian.com/uk/rss",
    #"Al Jazeera": "https://www.aljazeera.com/xml/rss/all.xml"
}

# %%
# MongoDB Setup
client = MongoClient('mongodb://localhost:27017/')  # Update with your MongoDB connection URI
db = client['news_database']
collection = db['news_articles']

# %%
def parse_rss_feed(feed_url):
    """Fetch and parse RSS feed"""
    feed = feedparser.parse(feed_url)
    articles = []
    
    for entry in feed.entries:
        # Extract the fields you need
        article = {
            'title': entry.title,
            'link': entry.link,
            'published': entry.published if 'published' in entry else None,
            'summary': entry.summary if 'summary' in entry else None,
            'description': fetch_full_article(entry.link),  # Fetch full content from the article link
            'source': feed.feed.title,
            'fetched_at': datetime.now(),
            'tag': assign_tag(entry)  # Add the tag field here
        }
        articles.append(article)
    
    return articles

# %%
def assign_tag(entry):
    """Assign a specific tag to an article based on custom logic"""
    if 'breaking' in entry.title.lower():
        return 1  # Tag for breaking news
    elif 'covid' in entry.title.lower():
        return 2  # Tag for COVID-related news
    elif 'election' in entry.title.lower():
        return 3  # Tag for election news
    else:
        return 0  # Default tag for other news

# %%
def is_duplicate_article(new_article, existing_articles):
    """Check if the new article is a duplicate based on title similarity using rapidfuzz."""
    for article in existing_articles:
        similarity = fuzz.token_set_ratio(new_article['title'], article['title'])
        if similarity > 85:  # Threshold for considering articles as duplicates
            print(f"Duplicate title found: {article['title']}")
            return True
    return False

# %%
def save_articles_to_mongo(articles):
    """Save articles to MongoDB, avoiding duplicates based on title similarity across sources."""
    # Fetch all existing articles from the database for comparison
    existing_articles = list(collection.find({}, {'title': 1}))  # Only fetch titles for comparison

    for article in articles:
        # Print the article details to the console before saving
        print(f"Title: {article['title']}")
        print(f"Link: {article['link']}")
        print(f"Published: {article['published']}")
        print(f"Summary: {article['summary']}")
        print(f"Description: {article['description']}")
        print(f"Source: {article['source']}")
        print(f"Tag: {article['tag']}")
        print(f"Fetched at: {article['fetched_at']}")
        print("=" * 40)  # Separator line

        # Check for duplicate articles based on title similarity
        if not is_duplicate_article(article, existing_articles):
            collection.insert_one(article)
            print(f"Saved article: {article['title']}")
        else:
            print(f"Duplicate article skipped: {article['title']}")

# %%
def fetch_full_article(url):
    """Fetch the full article content by scraping the article's page"""
    try:
        response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})  # Adding User-Agent for better compatibility
        soup = BeautifulSoup(response.content, 'html.parser')

        # Try extracting paragraphs from common HTML structures
        paragraphs = soup.find_all('p')  # Most news sites use <p> for paragraphs
        if not paragraphs:
            # Some websites use <div> with specific classes, adjust according to your target websites
            content_div = soup.find('div', {'class': 'article-content'})
            if content_div:
                paragraphs = content_div.find_all('p')
        
        # Join all paragraph texts to form the full article content
        full_text = ' '.join([p.get_text() for p in paragraphs])

        # Return the full content if paragraphs were found, otherwise return a default message
        return full_text if full_text else "Full content not available"
    
    except Exception as e:
        print(f"Failed to fetch full content from {url}: {e}")
        return "Failed to fetch full content"

# %%
def fetch_full_article(url):
    """Try to fetch article content using requests and BeautifulSoup, fall back to Selenium."""
    try:
        # First attempt using requests and BeautifulSoup
        response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
        soup = BeautifulSoup(response.content, 'html.parser')

        # Attempt to extract paragraphs directly
        paragraphs = soup.find_all('p')
        full_text = ' '.join([p.get_text() for p in paragraphs])

        # If no content found, fall back to Selenium
        if not full_text:
            full_text = fetch_full_article_with_selenium(url)

        return full_text if full_text else "Full content not available"
    
    except Exception as e:
        print(f"Failed to fetch full content from {url}: {e}")
        return "Failed to fetch full content"

# %%
def fetch_full_article_with_selenium(url):
    """Fetch full article content using Selenium for dynamically loaded pages."""
    try:
        options = Options()
        options.add_argument('--headless')
        options.add_argument('--no-sandbox')
        options.add_argument('--disable-dev-shm-usage')

        service = Service('/path/to/chromedriver')  # Update the path to your ChromeDriver
        driver = webdriver.Chrome(service=service, options=options)

        driver.get(url)
        driver.implicitly_wait(10)

        paragraphs = driver.find_elements(By.TAG_NAME, 'p')
        full_text = ' '.join([p.text for p in paragraphs])

        driver.quit()
        return full_text if full_text else "Full content not available"
    
    except Exception as e:
        print(f"Failed to fetch full content from {url}: {e}")
        return "Failed to fetch full content"

# %%
def crawl_news():
    """Crawl all news outlets and save to MongoDB"""
    for source, url in rss_feeds.items():
        print(f"Crawling articles from: {source}")
        articles = parse_rss_feed(url)
        save_articles_to_mongo(articles)

# %%
if __name__ == "__main__":
    crawl_news()
# Out:
# Crawling articles from: BBC News
# Failed to fetch full content from https://www.bbc.com/news/articles/cjd58p1g515o: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/cm249ym44dvo: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/cwyek8pgy7po: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/cy0l19j9jgko: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/cly2d829dgyo: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/cgey0vvxxw7o: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/ce8v4467806o: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/cm2yrpxxzmpo: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/c93yenv5r74o: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/c4gdxy4d5vno: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/c1e8q50y3v7o: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/videos/cm249d0l4dlo: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/c981q381p58o: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/videos/ce8v4kgd5zro: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.co.uk/news/10628994: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/sport/tennis/articles/cyvy9dervqzo: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/c870e9xq7jwo: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/c05gd83vnj7o: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/cd6qz387qjgo: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/c2dp7dk5g27o: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/cx2lr0jd37xo: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/cyvy5l7rjqgo: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/crl8110w0wdo: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/c0kjrp2rngzo: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/c2lnw2gvllxo: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/cd98vpxgp7ko: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/c07n005n3mno: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/cm2yrx8yny2o: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/c206djljel1o: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.co.uk/sounds/play/p0jwn7hf: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.co.uk/sounds/play/w3ct6dtl: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/sport/cricket/articles/c93p72xk13do: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/sport/tennis/articles/cyvy9dervqzo: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/sport/tennis/videos/cm2851gnjx3o: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/sport/football/articles/cwy93k37l4lo: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/sport/tennis/articles/cy801wdv8p1o: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/c2kd331l307o: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/cdd4qq4djemo: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/c05gd83vnj7o: name 'requests' is not defined
# Failed to fetch full content from https://www.bbc.com/news/articles/crkd1p4dmxzo: name 'requests' is not defined
# Title: 22 killed in Israeli strike on Beirut, Lebanon says
# Link: https://www.bbc.com/news/articles/cjd58p1g515o
# Published: Thu, 10 Oct 2024 21:13:37 GMT
# Summary: Lebanese officials say 22 people have been killed and 117 injured in Israeli strikes on two busy neighbourhoods in Beirut.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749556
# ========================================
# Duplicate title found: 22 killed in Israeli strike on Beirut, Lebanon says
# Duplicate article skipped: 22 killed in Israeli strike on Beirut, Lebanon says
# Title: Kate meets Southport families in surprise first visit since chemo
# Link: https://www.bbc.com/news/articles/cm249ym44dvo
# Published: Thu, 10 Oct 2024 21:33:23 GMT
# Summary: The Prince and Princess of Wales met bereaved families of children killed in a knife attack in Southport.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749585
# ========================================
# Duplicate title found: Kate meets Southport families in surprise first visit since chemo
# Duplicate article skipped: Kate meets Southport families in surprise first visit since chemo
# Title: Accused men confronted with abuse videos in French mass rape trial
# Link: https://www.bbc.com/news/articles/cwyek8pgy7po
# Published: Thu, 10 Oct 2024 17:02:14 GMT
# Summary: Fifty men are accused of raping Gisèle Pelicot after her husband drugged her and left her unconscious.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749603
# ========================================
# Duplicate title found: Accused men confronted with abuse videos in French mass rape trial
# Duplicate article skipped: Accused men confronted with abuse videos in French mass rape trial
# Title: How will the changes to workers' rights  affect you?
# Link: https://www.bbc.com/news/articles/cy0l19j9jgko
# Published: Thu, 10 Oct 2024 16:29:49 GMT
# Summary: A major shake-up of workers' rights is on its way, but what impact will it have?
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749620
# ========================================
# Duplicate title found: How will the changes to workers' rights  affect you?
# Duplicate article skipped: How will the changes to workers' rights  affect you?
# Title: Letby emailed colleagues asking them to be supportive, inquiry hears
# Link: https://www.bbc.com/news/articles/cly2d829dgyo
# Published: Thu, 10 Oct 2024 15:44:04 GMT
# Summary: The nurse told colleagues she had been "exonerated" and asked them to be "supportive", an inquiry hears.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749636
# ========================================
# Duplicate title found: Letby emailed colleagues asking them to be supportive, inquiry hears
# Duplicate article skipped: Letby emailed colleagues asking them to be supportive, inquiry hears
# Title: EU delays introduction of border check system again
# Link: https://www.bbc.com/news/articles/cgey0vvxxw7o
# Published: Thu, 10 Oct 2024 20:13:54 GMT
# Summary: The EU pushes back introducing new biometric border checks that were due on 10 November.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749653
# ========================================
# Duplicate title found: EU delays introduction of border check system again
# Duplicate article skipped: EU delays introduction of border check system again
# Title: Man jailed for pushing postman on to Tube tracks
# Link: https://www.bbc.com/news/articles/ce8v4467806o
# Published: Thu, 10 Oct 2024 15:21:24 GMT
# Summary: A man who pushed a postman in front of an oncoming Tube train is jailed after being convicted of attempted murder.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749668
# ========================================
# Duplicate title found: Man jailed for pushing postman on to Tube tracks
# Duplicate article skipped: Man jailed for pushing postman on to Tube tracks
# Title: Sue Gray will not attend summit in new regions role
# Link: https://www.bbc.com/news/articles/cm2yrpxxzmpo
# Published: Thu, 10 Oct 2024 16:09:05 GMT
# Summary: The prime minister's ex-chief of staff will not immediately take up a new role as his regional envoy.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749691
# ========================================
# Duplicate title found: Sue Gray will not attend summit in new regions role
# Duplicate article skipped: Sue Gray will not attend summit in new regions role
# Title: Fresh rise in mortgage rates predicted
# Link: https://www.bbc.com/news/articles/c93yenv5r74o
# Published: Thu, 10 Oct 2024 10:50:38 GMT
# Summary: Recent falls in rates could come to "an abrupt halt" in the next few days, according to brokers
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749710
# ========================================
# Duplicate title found: Fresh rise in mortgage rates predicted
# Duplicate article skipped: Fresh rise in mortgage rates predicted
# Title: Striking photos show the extent of Milton's devastation
# Link: https://www.bbc.com/news/articles/c4gdxy4d5vno
# Published: Thu, 10 Oct 2024 21:01:46 GMT
# Summary: Hurricane Milton lashed Florida and Cuba on Wednesday and Thursday, with storm surges, flooding and tornadoes causing serious damage.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749727
# ========================================
# Duplicate title found: Striking photos show the extent of Milton's devastation
# Duplicate article skipped: Striking photos show the extent of Milton's devastation
# Title: How hurricane conspiracy theories took over social media
# Link: https://www.bbc.com/news/articles/c1e8q50y3v7o
# Published: Thu, 10 Oct 2024 21:57:21 GMT
# Summary: The misinformation has been fuelled by a social media universe that rewards engagement over truth.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749744
# ========================================
# Saved article: How hurricane conspiracy theories took over social media
# Title: Watch: Damage assessed after hurricane blasts through Florida
# Link: https://www.bbc.com/news/videos/cm249d0l4dlo
# Published: Thu, 10 Oct 2024 17:36:59 GMT
# Summary: The deadly storm brought tornadoes, floods and storm surges, destroying homes and leaving millions without power.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749761
# ========================================
# Duplicate title found: Watch: Damage assessed after hurricane blasts through Florida
# Duplicate article skipped: Watch: Damage assessed after hurricane blasts through Florida
# Title: Where is Hurricane Milton now?
# Link: https://www.bbc.com/news/articles/c981q381p58o
# Published: Thu, 10 Oct 2024 21:13:55 GMT
# Summary: Milton hit western Florida near Siesta Key, with US officials warning of "life-threatening" storm surge.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749776
# ========================================
# Duplicate title found: Where is Hurricane Milton now?
# Duplicate article skipped: Where is Hurricane Milton now?
# Title: Sheriff rescues 14-year-old stranded on floating hurricane debris
# Link: https://www.bbc.com/news/videos/ce8v4kgd5zro
# Published: Thu, 10 Oct 2024 18:30:06 GMT
# Summary: The teenager was found alone in a flooded area of Hillsborough County in Florida.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749791
# ========================================
# Duplicate title found: Sheriff rescues 14-year-old stranded on floating hurricane debris
# Duplicate article skipped: Sheriff rescues 14-year-old stranded on floating hurricane debris
# Title: Download now
# Link: https://www.bbc.co.uk/news/10628994
# Published: Tue, 20 Aug 2024 11:35:33 GMT
# Summary: Top stories, breaking news, live reporting, and follow news topics that match your interests
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749807
# ========================================
# Duplicate title found: Download now
# Duplicate article skipped: Download now
# Title: 'The son every mum would love to have' - Nadal's enduring legacy
# Link: https://www.bbc.com/sport/tennis/articles/cyvy9dervqzo
# Published: Thu, 10 Oct 2024 13:49:16 GMT
# Summary: BBC tennis correspondent Russell Fuller on Rafael Nadal's rivalry with Roger Federer and his legacy as he announces his retirement next month.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749822
# ========================================
# Duplicate title found: 'The son every mum would love to have' - Nadal's enduring legacy
# Duplicate article skipped: 'The son every mum would love to have' - Nadal's enduring legacy
# Title: Elton John film documents singer's farewell tour
# Link: https://www.bbc.com/news/articles/c870e9xq7jwo
# Published: Thu, 10 Oct 2024 17:57:37 GMT
# Summary: A new documentary, Never Give Up, sees the singer revisit the LA venue he first played in 1975.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749838
# ========================================
# Duplicate title found: Elton John film documents singer's farewell tour
# Duplicate article skipped: Elton John film documents singer's farewell tour
# Title: My wife was everything, and depression took her, reflects ex-rugby star Hastings
# Link: https://www.bbc.com/news/articles/c05gd83vnj7o
# Published: Thu, 10 Oct 2024 12:52:47 GMT
# Summary: The former rugby star has told how his wife struggled with depression for 20 years before her death last month.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749853
# ========================================
# Duplicate title found: My wife was everything, and depression took her, reflects ex-rugby star Hastings
# Duplicate article skipped: My wife was everything, and depression took her, reflects ex-rugby star Hastings
# Title: Dinner plates and a single boot: Shackleton’s lost ship as never seen before
# Link: https://www.bbc.com/news/articles/cd6qz387qjgo
# Published: Thu, 10 Oct 2024 01:50:56 GMT
# Summary: A new 3D scan shows Endurance exactly as it is 3,000m down in Antarctica’s icy waters.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749870
# ========================================
# Duplicate title found: Dinner plates and a single boot: Shackleton’s lost ship as never seen before
# Duplicate article skipped: Dinner plates and a single boot: Shackleton’s lost ship as never seen before
# Title: Kylie Minogue on 'nasty' critics and how she kept every supportive cancer letter
# Link: https://www.bbc.com/news/articles/c2dp7dk5g27o
# Published: Thu, 10 Oct 2024 00:48:32 GMT
# Summary: The pop star discusses backstage tensions, a surprise duet with Madonna and her love of word games.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749904
# ========================================
# Duplicate title found: Kylie Minogue on 'nasty' critics and how she kept every supportive cancer letter
# Duplicate article skipped: Kylie Minogue on 'nasty' critics and how she kept every supportive cancer letter
# Title: The two forces at work on Biden-Netanyahu phone call
# Link: https://www.bbc.com/news/articles/cx2lr0jd37xo
# Published: Wed, 09 Oct 2024 23:14:57 GMT
# Summary: The US fears getting dragged into a war with Iran, while some Israelis want to deal it a body blow, Jeremy Bowen writes.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749921
# ========================================
# Duplicate title found: The two forces at work on Biden-Netanyahu phone call
# Duplicate article skipped: The two forces at work on Biden-Netanyahu phone call
# Title: Nostalgic 1950s photos that were almost lost for ever
# Link: https://www.bbc.com/news/articles/cyvy5l7rjqgo
# Published: Thu, 10 Oct 2024 05:44:39 GMT
# Summary: A series of images from the era have emerged more than a decade after they were almost thrown away.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749937
# ========================================
# Duplicate title found: Nostalgic 1950s photos that were almost lost for ever
# Duplicate article skipped: Nostalgic 1950s photos that were almost lost for ever
# Title: Officer 'sorry' for 'necessary' shooting, court told
# Link: https://www.bbc.com/news/articles/crl8110w0wdo
# Published: Thu, 10 Oct 2024 15:01:37 GMT
# Summary: A police officer who killed an unarmed man has told the Old Bailey he did it to save his own life.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749953
# ========================================
# Duplicate title found: Officer 'sorry' for 'necessary' shooting, court told
# Duplicate article skipped: Officer 'sorry' for 'necessary' shooting, court told
# Title: BBC Weather fault forecasts hurricanes across world
# Link: https://www.bbc.com/news/articles/c0kjrp2rngzo
# Published: Thu, 10 Oct 2024 19:32:28 GMT
# Summary: "Don't be alarmed folks," says weather presenter Matt Taylor after a data glitch on the site.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749968
# ========================================
# Duplicate title found: BBC Weather fault forecasts hurricanes across world
# Duplicate article skipped: BBC Weather fault forecasts hurricanes across world
# Title: UN accuses Israel of war crimes over attacks on Gaza hospitals
# Link: https://www.bbc.com/news/articles/c2lnw2gvllxo
# Published: Thu, 10 Oct 2024 18:49:41 GMT
# Summary: UN investigators say Israel is deliberately targeting health facilities and killing medical workers in Gaza.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.749984
# ========================================
# Duplicate title found: UN accuses Israel of war crimes over attacks on Gaza hospitals
# Duplicate article skipped: UN accuses Israel of war crimes over attacks on Gaza hospitals
# Title: Covid inquiry told of trust do-not-resuscitate rule
# Link: https://www.bbc.com/news/articles/cd98vpxgp7ko
# Published: Thu, 10 Oct 2024 16:54:11 GMT
# Summary: Patients' families were “horrified but not surprised” when told the blanket policy had been in place.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 2
# Fetched at: 2024-10-11 03:44:50.750000
# ========================================
# Duplicate title found: Covid inquiry told of trust do-not-resuscitate rule
# Duplicate article skipped: Covid inquiry told of trust do-not-resuscitate rule
# Title: Alleged Iranian spy asked MI6 to be double agent, court hears, as messages revealed
# Link: https://www.bbc.com/news/articles/c07n005n3mno
# Published: Thu, 10 Oct 2024 18:33:25 GMT
# Summary: Daniel Khalife twice tried to contact MI6 and offered to be a double agent, a court hears.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.750026
# ========================================
# Duplicate title found: Alleged Iranian spy asked MI6 to be double agent, court hears, as messages revealed
# Duplicate article skipped: Alleged Iranian spy asked MI6 to be double agent, court hears, as messages revealed
# Title: Portugal tries to tempt under-35s with tax cuts
# Link: https://www.bbc.com/news/articles/cm2yrx8yny2o
# Published: Thu, 10 Oct 2024 15:03:52 GMT
# Summary: Luís Montenegro's centre-right government wants to dissuade young people from emigrating and encourage foreigners to settle in Portugal.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.750043
# ========================================
# Duplicate title found: Portugal tries to tempt under-35s with tax cuts
# Duplicate article skipped: Portugal tries to tempt under-35s with tax cuts
# Title: South Korea's Han Kang wins Nobel Literature Prize
# Link: https://www.bbc.com/news/articles/c206djljel1o
# Published: Thu, 10 Oct 2024 12:05:13 GMT
# Summary: Han Kang is the first South Korean winner and only the 18th woman to win the Nobel literature prize.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.750059
# ========================================
# Duplicate title found: South Korea's Han Kang wins Nobel Literature Prize
# Duplicate article skipped: South Korea's Han Kang wins Nobel Literature Prize
# Title: Hurricane Milton and a storm of misinformation
# Link: https://www.bbc.co.uk/sounds/play/p0jwn7hf
# Published: Thu, 10 Oct 2024 15:34:00 GMT
# Summary: Joe Biden said misinformation was making people "panic".
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.750074
# ========================================
# Duplicate title found: Hurricane Milton and a storm of misinformation
# Duplicate article skipped: Hurricane Milton and a storm of misinformation
# Title: Three weeks that changed life in Lebanon
# Link: https://www.bbc.co.uk/sounds/play/w3ct6dtl
# Published: Thu, 10 Oct 2024 08:55:00 GMT
# Summary: Israeli air strikes have forced more than 1.2 million Lebanese to flee their homes
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.750091
# ========================================
# Duplicate title found: Three weeks that changed life in Lebanon
# Duplicate article skipped: Three weeks that changed life in Lebanon
# Title: Eight-hundred-and-twenty-three! The spirit behind England's record-breaking day
# Link: https://www.bbc.com/sport/cricket/articles/c93p72xk13do
# Published: Thu, 10 Oct 2024 18:09:03 GMT
# Summary: England's record-breaking runscoring is testament to their incredible spirit, says chief cricket writer Stephan Shemilt
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 1
# Fetched at: 2024-10-11 03:44:50.750108
# ========================================
# Duplicate title found: Eight-hundred-and-twenty-three! The spirit behind England's record-breaking day
# Duplicate article skipped: Eight-hundred-and-twenty-three! The spirit behind England's record-breaking day
# Title: 'The son every mum would love to have' - Nadal, Federer & an enduring legacy
# Link: https://www.bbc.com/sport/tennis/articles/cyvy9dervqzo
# Published: Thu, 10 Oct 2024 13:49:16 GMT
# Summary: BBC tennis correspondent Russell Fuller on Rafael Nadal's enduring rivalry with Roger Federer and his legacy in the tennis world.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.750122
# ========================================
# Duplicate title found: 'The son every mum would love to have' - Nadal's enduring legacy
# Duplicate article skipped: 'The son every mum would love to have' - Nadal, Federer & an enduring legacy
# Title: How 'genius' Nadal won 22 Grand Slams - including Wimbledon epic
# Link: https://www.bbc.com/sport/tennis/videos/cm2851gnjx3o
# Published: Thu, 10 Oct 2024 12:21:41 GMT
# Summary: BBC Sport pays tribute to Rafael Nadal's incredible career and looks back at the 2008 Wimbledon final, after the 22-time Grand Slam winner announced he will be retiring at the end of the season.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.750138
# ========================================
# Duplicate title found: How 'genius' Nadal won 22 Grand Slams - including Wimbledon epic
# Duplicate article skipped: How 'genius' Nadal won 22 Grand Slams - including Wimbledon epic
# Title: England & Greece pay tribute to Baldock at Wembley
# Link: https://www.bbc.com/sport/football/articles/cwy93k37l4lo
# Published: Thu, 10 Oct 2024 19:20:33 GMT
# Summary: England and Greece players hold a minute's silence in memory of George Baldock before Thursday's Nations League match at Wembley.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.750154
# ========================================
# Duplicate title found: England & Greece pay tribute to Baldock at Wembley
# Duplicate article skipped: England & Greece pay tribute to Baldock at Wembley
# Title: Djokovic & Federer lead tributes to retiring Nadal
# Link: https://www.bbc.com/sport/tennis/articles/cy801wdv8p1o
# Published: Thu, 10 Oct 2024 18:33:34 GMT
# Summary: Rafael Nadal is described as a "legend" and "one of the greatest of all time" after the tennis icon confirms he will retire at the end of this season.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.750170
# ========================================
# Duplicate title found: Djokovic & Federer lead tributes to retiring Nadal
# Duplicate article skipped: Djokovic & Federer lead tributes to retiring Nadal
# Title: Dead child was undiscovered in garden for years
# Link: https://www.bbc.com/news/articles/c2kd331l307o
# Published: Thu, 10 Oct 2024 18:10:00 GMT
# Summary: Tai and Naiyahmi Yasharahyalah are accused of allowing or causing the death of their son, Abiyah.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.750186
# ========================================
# Duplicate title found: Dead child was undiscovered in garden for years
# Duplicate article skipped: Dead child was undiscovered in garden for years
# Title: Woman goes on trial accused of murdering her partner
# Link: https://www.bbc.com/news/articles/cdd4qq4djemo
# Published: Thu, 10 Oct 2024 16:55:10 GMT
# Summary: The trial into the murder of a man in west Belfast has started at Coleraine Courthouse.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.750201
# ========================================
# Duplicate title found: Woman goes on trial accused of murdering her partner
# Duplicate article skipped: Woman goes on trial accused of murdering her partner
# Title: My wife was everything, and depression took her - Scott Hastings
# Link: https://www.bbc.com/news/articles/c05gd83vnj7o
# Published: Thu, 10 Oct 2024 12:52:47 GMT
# Summary: The former rugby star has told how his wife struggled with depression for 20 years before her death last month.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.750230
# ========================================
# Duplicate title found: My wife was everything, and depression took her, reflects ex-rugby star Hastings
# Duplicate article skipped: My wife was everything, and depression took her - Scott Hastings
# Title: Plaid Cymru leader to unveil vision to help NHS
# Link: https://www.bbc.com/news/articles/crkd1p4dmxzo
# Published: Thu, 10 Oct 2024 22:02:00 GMT
# Summary: Rhun ap Iorwerth says his party would pursue a "preventative" approach to support the NHS.
# Description: Failed to fetch full content
# Source: BBC News
# Tag: 0
# Fetched at: 2024-10-11 03:44:50.750246
# ========================================
# Duplicate title found: Plaid Cymru leader to unveil vision to help NHS
# Duplicate article skipped: Plaid Cymru leader to unveil vision to help NHS
